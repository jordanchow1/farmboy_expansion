# %%
import pandas as pd

stores = pd.read_csv('farmboy_stores.csv')

# Extract FSA from the Address column (first 3 characters of postal code)
stores['FSA'] = stores['Address'].str.extract(r'([A-Z]\d[A-Z])')

census_data = pd.read_csv('ontario_fsa.csv')
# Merge the datasets
merged_data = stores.merge(census_data, on='FSA', how='left')

# Check the result
print(merged_data.head(10))
# Out:
#      Store Name                                            Address  FSA  \
# 0     Alderwood  841 Brown's Line, Shoppes of Alderwood, Toront...  M8W
# 1       Aukland             5245 Dundas St W, Toronto, ON, M9B 1A5  M9B
# 2        Aurora   10 Goulding Avenue, Unit A1, Aurora, ON, L4G 7B8  L4G
# 3     Barrhaven         3033 Woodroffe Avenue, Ottawa, ON, K2G 6H2  K2G
# 4   Beaverbrook       1415 Beaverbrook Avenue, London, ON, N6H 0J1  N6H
# 5  Blossom Park              2950 Bank Street, Ottawa, ON, K1T 1N8  K1T
# 6    Blue Heron              1500 Bank Street, Ottawa, ON, K1H 7Z1  K1H
# 7     Brantford       240 King George Road, Brantford, ON, N3R 5L4  N3R
# 8     Britannia            1495 Richmond Road, Ottawa, ON, K2B 6R9  K2B
# 9        Bronte    2441 Lakeshore Road West, Oakville, ON, L6L 5V5  L6L
#
#    LANDAREA  Bachelor's degree or higher  Car, truck or van - as a driver  \
# 0    6.9498                       5780.0                           4990.0
# 1   13.3122                       9790.0                           6425.0
# 2   50.0005                      17045.0                          15165.0
# 3   28.2119                      12710.0                          10190.0
# 4   33.7630                      10820.0                          10310.0
# 5   46.4052                       9575.0                           8530.0
# 6    6.8364                       5095.0                           2505.0
# 7   16.4913                       3655.0                          10860.0
# 8    7.9454                       7615.0                           5325.0
# 9   17.0665                       8015.0                           5995.0
#
#    Car, truck or van - as a passenger  Couple-family households  Employed  \
# 0                               500.0                    4445.0   11365.0
# 1                               660.0                    6935.0   16040.0
# 2                              1160.0                   13420.0   30165.0
# 3                              1240.0                   10055.0   24685.0
# 4                              1060.0                    8910.0   19270.0
# 5                              1025.0                    7605.0   18660.0
# 6                               250.0                    3535.0    7625.0
# 7                              1055.0                    7665.0   15820.0
# 8                               795.0                    5795.0   14305.0
# 9                               470.0                    6860.0   13110.0
#
#    Employee  Median age of the population  \
# 0   10630.0                          41.6
# 1   14600.0                          42.0
# 2   26745.0                          42.0
# 3   23645.0                          40.0
# 4   18385.0                          38.8
# 5   17790.0                          36.0
# 6    6785.0                          44.0
# 7   15580.0                          45.6
# 8   14335.0                          39.6
# 9   11405.0                          47.2
#
#    Median total income of household in 2020 ($)  Permanent position  \
# 0                                       95000.0              9295.0
# 1                                      108000.0             12380.0
# 2                                      119000.0             22475.0
# 3                                      114000.0             19505.0
# 4                                       71000.0             14430.0
# 5                                      107000.0             14495.0
# 6                                      103000.0              5430.0
# 7                                       83000.0             13740.0
# 8                                       72000.0             11660.0
# 9                                      122000.0              9620.0
#
#    Population, 2021  Temporary position  With children  population_density
# 0           22381.0              1330.0          260.0         3220.380443
# 1           33236.0              2225.0          285.0         2496.657202
# 2           62061.0              4270.0          570.0         1241.207588
# 3           50692.0              4135.0          540.0         1796.830416
# 4           44215.0              3955.0          410.0         1309.569647
# 5           40054.0              3300.0          470.0          863.136028
# 6           16306.0              1355.0          150.0         2385.173483
# 7           35858.0              1840.0          700.0         2174.358601
# 8           33254.0              2675.0          345.0         4185.314773
# 9           30012.0              1780.0          250.0         1758.532798

# %%
merged_data.to_csv('merged_data.csv', index=False)
